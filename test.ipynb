# %%
import sqlite3
def get_products(seller_name):
    conn = sqlite3.connect('digikala_database.db')
    cursor = conn.cursor()
    query = f'SELECT product_name FROM products WHERE seller_name = "{seller_name}"'
    cursor.execute(query)
    result = cursor.fetchall()
    result = [product[0] for product in result]
    return result
def get_all_products():
    conn = sqlite3.connect('digikala_database.db')
    cursor = conn.cursor()
    query = f'SELECT product_name FROM products '
    cursor.execute(query)
    result = cursor.fetchall()
    result = [product[0] for product in result]
    return result

def get_all_seller_name():
    conn = sqlite3.connect('digikala_database.db')
    cursor = conn.cursor()
    query = f'SELECT seller_name FROM sellers '
    cursor.execute(query)
    result = cursor.fetchall()
    result = [product[0] for product in result]
    return result


def get_category(details):
    categories_list = []
    for main_category, sub_categories in details.items():
        for sub_category, items in sub_categories.items():
            categories_list.append(f"{main_category} - {sub_category}")
            for item in items:
                categories_list.append(f"{main_category} - {sub_category} - {item}")

    return categories_list
def get_all_categories():
    with open('details.txt','r',encoding='utf-8-sig') as file :
        result = file.read()
        result = eval(result)
    return result

def get_seller_products_dict():
    all_seller = get_all_seller_name()
    sellers_products = {}
    for seller in all_seller:
        sellers_products[seller] = get_products(seller)
    return sellers_products
# Out:
# {'اکتشاف': ['دوربین مداربسته تحت شبکه شیائومی مدل c400'], 'اکو بیس': ['پرینتر حرارتی مدل خرگوشی', 'دوربین فیلم برداری ورزشی مدل A9', 'ساعت هوشمند هاینو تکو مدل T93 Ultra Max', 'ماساژور برقی مدل پروانه ای', 'کابل تبدیل USB به USB-C مدل Fast Charge 5A طول 1 متر', 'هدفون بلوتوثی مدل M19', 'بند مدل Ocean مناسب برای اپل واچ 42/44/45/49 میلی متری', 'پخش کننده اف ام خودرو مدل carg7 ', 'کابل تبدیل USB به USB-C مدل TURBO CHARGER طول 1 متر', 'اسپیکر بلوتوثی قابل حمل  کی تی اس مدل KT-1576', 'هدست بلوتوثی ای ال وی مدل M19', 'پخش کننده اف ام خودرو مدل CARG7', 'هدست بلوتوثی مدل Airpod2 کد pro5', 'اسپیکر قابل حمل کی تی اس مدل 1185', 'میکروفون مدل سرود کد ECORA18 ', 'کابل شارژ بی سیم مدل LC-SW520 مناسب برای ساعت هوشمند لوکا LC-SW520', 'هدفون بی سیم مدل P47 wireless 2-2022', 'شارژر دیواری سامسونگ مدل 0009', 'کابل تبدیل USB به USB-C مدل SUPER FAST_PLUS طول 1 متر', 'مبدل OTG USB-C به USB مدل S10TC', 'اسپیکر قابل حمل ای ال وی مدل KTS-1185', 'پخش کننده اف ام خودرو کار جی 7 مدل S18', 'اسپیکر بلوتوثی قابل حمل ای ال وی مدل KTS-1338', 'کابل تبدیل USB به USB-C دنمن مدل D01T طول 1 متر', 'هندزفری بلوتوثی مدل buku', 'کابل تبدیل USB به USB-C مدل TURBO PLUS طول 1 متر', 'شارژر دیواری شیائومی مدل MDY-11-ED 67', 'کابل تبدیل USB به USB-C مدل M01 طول یک متر', 'شارژر دیواری  مدل MDY-11-EZ-33W-QC.4.0 به همراه کابل تبدیل USB-C', 'کابل تبدیل USB به USB-C مدل پوکو طول 0.95 متر', 'کابل تبدیل USB به USB-C  دنمن  مدلd06t  طول 1 متر', 'اسپیکر بلوتوثی قابل حمل مدل GTS-1389', 'شارژر دیواری کامانتی مدل KT-35QC3 20w به همراه کابل تبدیل MicroUsb ', 'مبدل USB-C به جک 3.5 ایکس هانز مدل TC12', 'هندزفری ایکس هانز مدل S8', 'اسپیکر بلوتوثی قابل حمل مدل ZQS8210', 'ساعت هوشمند مدل T500 Ultra', 'دوربین مداربسته تحت شبکه مدل A9', 'شارژر دیواری شیائومی مدل 67 وات به همراه کابل تبدیل USB-C', 'هدفون بلوتوثی مدل P47 2022 V5', 'اسپیکر بلوتوثی قابل حمل مدل KTS-1199', 'هنذفری مدل Champ', 'هدفون بی سیم مدل P47 new version 5.0EDR', 'شارژر دیواری شیائومی مدل MDY-11-EZ 33w', 'اسپیکر بلوتوثی قابل حمل مدل KTS1338 NEW', 'هدفون مدل A324', 'هندزفری بلوتوثی مدل pro5', 'اسپیکر بلوتوثی قابل حمل کی تی اس مدل 1338', 'شارژر دیواری شیائومی مدل Mdy_12_Eh -  67w به همراه کابل USB-C', 'کابل تبدیل USB به USB-C مدل TURBO QS طول 1 متر', 'هدست بلوتوثی کد pro5', 'کابل تبدیل USB به USB-C دنمن مدل HIGH SPEED طول یک متر', 'میکروفون مدل DYNAMIC سیم سرخود', 'ماساژور برقی مدل پروانه ای کد 220 طرح LED', 'هندزفری بلوتوثی مدل AirPods Pro  2', 'ماساژور برقی مدل پروانه ای کد 220 مجموعه 2 عددی', 'هدست بلوتوثی مدل TWS-i18 5.3', 'کابل شارژ مغناطیسی ساعت هوشمند مدل 2023 طول 0.6 متر'], 'امنیت شهر': ['دوربین مداربسته آنالوگ برایتون مدل 102', 'دوربین مداربسته آنالوگ برایتون مدل 102', 'سیستم امنیتی برایتون مدل 4422', 'دوربین مداربسته آنالوگ برایتون مدل UVC222B49M2-C(2.8mm)', 'سیستم امنیتی برایتون مدل PK4BR94B19B', 'سیستم امنیتی برایتون مدل METAL4422', 'ضبط کننده ویدیویی برایتون مدل UVRA04-EMB-D74G-D', 'دوربین مداربسته آنالوگ برایتون مدل UVC222B1AR2-M', 'ضبط کننده ویدیویی برایتون مدل UVR04EMB', 'سیستم امنیتی برایتون مدل 105', 'سیستم امنیتی برایتون مدل PK6BR94B19B', 'سیستم امنیتی برایتون مدل PK8BR94B19B', 'سیستم امنیتی برایتون مدل 4001', 'سیستم امنیتی برایتون مدل METAL02', 'سیستم امنیتی برایتون \xa0کد 24b41', 'ضبط کننده ویدیویی برایتون مدل UVR A04EMB', 'سیستم امنیتی برایتون مدل\xa046r3', 'سیستم امنیتی برایتون مدل PK2BR94B19B', 'سیستم امنیتی برایتون مدل PK4BR77B19B-C', 'سیستم امنیتی برایتون مدل\xa024t41p', 'سیستم امنیتی برایتون مدل PK2BR78T02', 'سیستم امنیتی برایتون مدل PK4BR77D87N-D', 'ضبط کننده ویدیویی برایتون مدل UVRA04EMB Plus -D74G', 'سیستم امنیتی آنالوگ برایتون مدل P404D4', 'سیستم امنیتی برایتون مدل Perfect 2', 'سیستم امنیتی برایتون مدل 08EMB', 'سیستم امنیتی برایتون مدل PK2BR77D87N-D'], 'آراميد': ['هارددیسک اینترنال وسترن دیجیتال مدل Purple WD10PURZ ظرفیت 1 ترابایت', 'دوربین مداربسته آنالوگ برایتون مدل 102', 'دوربین مداربسته تحت شبکه مدل \xa0چرخشی', 'دوربین مداربسته آنالوگ داهوا مدل SE-4BP', 'دوربین مداربسته آنالوگ داهوا مدل DH-HAC-B1A21P', 'دوربین مداربسته آنالوگ برایتون مدل 102', 'پک سیستم امنیتی نظارتی دوربین مداربسته SX8008A',  ...
